# %% [markdown]
# # CS6930 Data Mining Fall 2017 Assignment 1
# Author: Hobey Wong

# %% [markdown]
# In this assignment, you are given the following 3 datasets. Each dataset has a training and a test file. Specifically, these files are:
# - dataset 1: train-100-10.csv test-100-10.csv
# - dataset 2: train-100-100.csv test-100-100.csv
# - dataset 3: train-1000-100.csv test-1000-100.csv

# %%
import modeling as mdl

# %% [markdown]
# 1. Start the experiment by creating 3 additional training files from the train-1000-100.csv by taking the first 50, 100, and 150 instances respectively.
# 2. Call them: train-50(1000)-100.csv, train-100(1000)-100.csv, train-150(1000)-100.csv. The corresponding test file for these dataset would be test-1000-100.csv and no modification is needed.

# %%
mdl.create_train_data()
# Out:
# 2021-02-09 11:28:58,275 - INFO - train-50(1000)-100 is saved!
# 2021-02-09 11:28:58,318 - INFO - train-100(1000)-100 is saved!
# 2021-02-09 11:28:58,430 - INFO - train-150(1000)-100 is saved!

# %% [markdown]
# ## L2 regularized linear regression algorithm

# %% [markdown]
# Q1. Implement L2 regularized linear regression algorithm with lambda ranging from 0 to 150 (integers only). For each of the 6 dataset, plot both the training set MSE and the test set MSE as a function of lambda (x-axis) in one graph.

# %%
train_dataset = ['train-100-10', 'train-100-100', 'train-1000-100',
                 'train-50(1000)-100', 'train-100(1000)-100', 'train-150(1000)-100']
test_dataset = ['test-100-10', 'test-100-100', 'test-1000-100',
                'test-1000-100', 'test-1000-100', 'test-1000-100']

# %% [markdown]
# ### Q1.(a) For each dataset, which lambda value gives the least test set MSE?

# %%
trn = train_dataset[0]
test = test_dataset[0]

mdl.plot_mse(trn_file_name=trn, test_file_name=test, min_lbda=0)
mdl.get_min_test_mse(trn_file_name=trn, test_file_name=test)
# Out:
# 2021-02-09 11:28:59,403 - INFO - tmp_res/train-100-10_mse_lambda_from_0 is saved!
# 2021-02-09 11:28:59,470 - INFO - For dataset train-100-10 & test-100-10, with λ = 9, we get min test MSE = 4.1597.

# %%
trn = train_dataset[1]
test = test_dataset[1]

mdl.plot_mse(trn_file_name=trn, test_file_name=test, min_lbda=0)
mdl.get_min_test_mse(trn_file_name=trn, test_file_name=test)
# Out:
# 2021-02-09 11:29:00,408 - INFO - tmp_res/train-100-100_mse_lambda_from_0 is saved!
# 2021-02-09 11:29:00,588 - INFO - For dataset train-100-100 & test-100-100, with λ = 22, we get min test MSE = 5.0728.

# %%
trn = train_dataset[2]
test = test_dataset[2]

mdl.plot_mse(trn_file_name=trn, test_file_name=test, min_lbda=0)
mdl.get_min_test_mse(trn_file_name=trn, test_file_name=test)
# Out:
# 2021-02-09 11:29:01,670 - INFO - tmp_res/train-1000-100_mse_lambda_from_0 is saved!
# 2021-02-09 11:29:01,963 - INFO - For dataset train-1000-100 & test-1000-100, with λ = 27, we get min test MSE = 4.3184.

# %%
trn = train_dataset[3]
test = test_dataset[3]

mdl.plot_mse(trn_file_name=trn, test_file_name=test, min_lbda=0)
mdl.get_min_test_mse(trn_file_name=trn, test_file_name=test)
# Out:
# 2021-02-09 11:29:02,580 - INFO - tmp_res/train-50(1000)-100_mse_lambda_from_0 is saved!
# 2021-02-09 11:29:02,767 - INFO - For dataset train-50(1000)-100 & test-1000-100, with λ = 8, we get min test MSE = 5.5123.

# %%
trn = train_dataset[4]
test = test_dataset[4]

mdl.plot_mse(trn_file_name=trn, test_file_name=test, min_lbda=0)
mdl.get_min_test_mse(trn_file_name=trn, test_file_name=test)
# Out:
# 2021-02-09 11:29:03,414 - INFO - tmp_res/train-100(1000)-100_mse_lambda_from_0 is saved!
# 2021-02-09 11:29:03,585 - INFO - For dataset train-100(1000)-100 & test-1000-100, with λ = 19, we get min test MSE = 5.1962.

# %%
trn = train_dataset[5]
test = test_dataset[5]

mdl.plot_mse(trn_file_name=trn, test_file_name=test, min_lbda=0)
mdl.get_min_test_mse(trn_file_name=trn, test_file_name=test)
# Out:
# 2021-02-09 11:29:04,027 - INFO - tmp_res/train-150(1000)-100_mse_lambda_from_0 is saved!
# 2021-02-09 11:29:04,170 - INFO - For dataset train-150(1000)-100 & test-1000-100, with λ = 24, we get min test MSE = 4.8437.

# %% [markdown]
# ### Q1.(b) For each of datasets 100-100, 50(1000)-100, 100(1000)-100, provide an additional graph with lambda ranging from 1 to 150.

# %%
trn = train_dataset[1]
test = test_dataset[1]
mdl.plot_mse(trn_file_name=trn, test_file_name=test, min_lbda=1)
# Out:
# 2021-02-09 11:29:04,592 - INFO - tmp_res/train-100-100_mse_lambda_from_1 is saved!

# %%
trn = train_dataset[3]
test = test_dataset[3]
mdl.plot_mse(trn_file_name=trn, test_file_name=test, min_lbda=1)
# Out:
# 2021-02-09 11:29:05,072 - INFO - tmp_res/train-50(1000)-100_mse_lambda_from_1 is saved!

# %%
trn = train_dataset[4]
test = test_dataset[4]
mdl.plot_mse(trn_file_name=trn, test_file_name=test, min_lbda=1)
# Out:
# 2021-02-09 11:29:05,469 - INFO - tmp_res/train-100(1000)-100_mse_lambda_from_1 is saved!

# %% [markdown]
# ### Q1.(c) Explain why lambda = 0 (i.e., no regularization) gives abnormally large MSEs for those three datasets in (b).

# %% [markdown]
# ## Cross Validation

# %% [markdown]
# ### Q1.(a) Using CV technique, what is the best choice of lambda value and the corresponding test set MSE for each of the six datasets?

# %%
trn = train_dataset[0]
test = test_dataset[0]

mdl.cross_validation(trn_file_name=trn, test_file_name=test, k_fold=10)
# Out:
# 2021-02-09 11:29:05,667 - INFO - For dataset train-100-10, after using 10-fold CV, we get min test MSE = 4.1735 with λ = 13.

# %%
trn = train_dataset[1]
test = test_dataset[1]

mdl.cross_validation(trn_file_name=trn, test_file_name=test, k_fold=10)
# Out:
# 2021-02-09 11:29:06,341 - INFO - For dataset train-100-100, after using 10-fold CV, we get min test MSE = 5.0768 with λ = 20.

# %%
trn = train_dataset[2]
test = test_dataset[2]

mdl.cross_validation(trn_file_name=trn, test_file_name=test, k_fold=10)
# Out:
# 2021-02-09 11:29:07,649 - INFO - For dataset train-1000-100, after using 10-fold CV, we get min test MSE = 4.3252 with λ = 39.

# %%
trn = train_dataset[3]
test = test_dataset[3]

mdl.cross_validation(trn_file_name=trn, test_file_name=test, k_fold=10)
# Out:
# 2021-02-09 11:29:08,197 - INFO - For dataset train-50(1000)-100, after using 10-fold CV, we get min test MSE = 5.8789 with λ = 24.

# %%
trn = train_dataset[4]
test = test_dataset[4]

mdl.cross_validation(trn_file_name=trn, test_file_name=test, k_fold=10)
# Out:
# 2021-02-09 11:29:08,766 - INFO - For dataset train-100(1000)-100, after using 10-fold CV, we get min test MSE = 5.2525 with λ = 31.

# %%
trn = train_dataset[5]
test = test_dataset[5]

mdl.cross_validation(trn_file_name=trn, test_file_name=test, k_fold=10)
# Out:
# 2021-02-09 11:29:09,368 - INFO - For dataset train-150(1000)-100, after using 10-fold CV, we get min test MSE = 4.929 with λ = 47.

# %% [markdown]
# ## Learning Curve

# %% [markdown]
# ### Fix lambda = 1, 25, 150. For each of these values, plot a learning curve for the algorithm using the dataset 1000-100.csv.

# %%
mdl.learning_curve(trn_file_name='train-1000-100', test_file_name='test-1000-100', lbda=1,
                   subset_size_step=10, repeat_times=50)
# Out:
# 2021-02-09 11:29:13,675 - INFO - tmp_res/train-1000-100_learning_curve_with_lambda_1 is saved!

# %%
mdl.learning_curve(trn_file_name='train-1000-100', test_file_name='test-1000-100', lbda=25,
                   subset_size_step=10, repeat_times=40)
# Out:
# 2021-02-09 11:31:50,118 - INFO - tmp_res/train-1000-100_learning_curve_with_lambda_25 is saved!

# %%
mdl.learning_curve(trn_file_name='train-1000-100', test_file_name='test-1000-100', lbda=150,
                   subset_size_step=40, repeat_times=30)
# Out:
# 2021-02-09 11:31:23,171 - INFO - tmp_res/train-1000-100_learning_curve_with_lambda_150 is saved!
